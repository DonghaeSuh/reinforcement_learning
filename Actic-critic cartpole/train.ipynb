# %%
import inspect

# %%
print(inspect.getfile(gym))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_40316/25357225.py in <module>
# ----> 1 print(inspect.getfile(gym))
#
# NameError: name 'gym' is not defined

# %%
import sys
import gym
import pylab
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import RandomUniform

# %%
# 정책 신경망과 가치 신경망 생성
class A2C(tf.keras.Model):
    def __init__(self, action_size):
        super(A2C, self).__init__()
        self.actor_fc = Dense(24, activation='tanh')
        self.actor_out = Dense(action_size, activation='softmax',
                               kernel_initializer=RandomUniform(-1e-3, 1e-3))
        self.critic_fc1 = Dense(24, activation='tanh')
        self.critic_fc2 = Dense(24, activation='tanh')
        self.critic_out = Dense(1,
                                kernel_initializer=RandomUniform(-1e-3, 1e-3))

    def call(self, x):
        actor_x = self.actor_fc(x)
        policy = self.actor_out(actor_x)

        critic_x = self.critic_fc1(x)
        critic_x = self.critic_fc2(critic_x)
        value = self.critic_out(critic_x)
        return policy, value

# %%
# 카트폴 예제에서의 액터-크리틱(A2C) 에이전트
class A2CAgent:
    def __init__(self, action_size):
        self.render = False

        # 행동의 크기 정의
        self.action_size = action_size

        # 액터-크리틱 하이퍼파라미터
        self.discount_factor = 0.99
        self.learning_rate = 0.001

        # 정책신경망과 가치신경망 생성
        self.model = A2C(self.action_size)
        # 최적화 알고리즘 설정, 미분값이 너무 커지는 현상을 막기 위해 clipnorm 설정
        self.optimizer = Adam(lr=self.learning_rate, clipnorm=5.0)

    # 정책신경망의 출력을 받아 확률적으로 행동을 선택
    def get_action(self, state):
        policy, _ = self.model(state)
        policy = np.array(policy[0])
        return np.random.choice(self.action_size, 1, p=policy)[0]

    # 각 타임스텝마다 정책신경망과 가치신경망을 업데이트
    def train_model(self, state, action, reward, next_state, done):
        model_params = self.model.trainable_variables
        with tf.GradientTape() as tape:
            policy, value = self.model(state)
            _, next_value = self.model(next_state)
            target = reward + (1 - done) * self.discount_factor * next_value[0]

            # 정책 신경망 오류 함수 구하기
            one_hot_action = tf.one_hot([action], self.action_size)
            action_prob = tf.reduce_sum(one_hot_action * policy, axis=1)
            cross_entropy = - tf.math.log(action_prob + 1e-5)
            advantage = tf.stop_gradient(target - value[0])
            actor_loss = tf.reduce_mean(cross_entropy * advantage)

            # 가치 신경망 오류 함수 구하기
            critic_loss = 0.5 * tf.square(tf.stop_gradient(target) - value[0])
            critic_loss = tf.reduce_mean(critic_loss)

            # 하나의 오류 함수로 만들기
            loss = 0.2 * actor_loss + critic_loss

        # 오류함수를 줄이는 방향으로 모델 업데이트
        grads = tape.gradient(loss, model_params)
        self.optimizer.apply_gradients(zip(grads, model_params))
        return np.array(loss)

# %%
if __name__ == "__main__":
    # CartPole-v1 환경, 최대 타임스텝 수가 500
    env = gym.make('CartPole-v1')
    # 환경으로부터 상태와 행동의 크기를 받아옴
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    # 액터-크리틱(A2C) 에이전트 생성
    agent = A2CAgent(action_size)

    scores, episodes = [], []
    score_avg = 0

    num_episode = 1000
    for e in range(num_episode):
        done = False
        score = 0
        loss_list = []
        state = env.reset()
        state = np.reshape(state, [1, state_size])

        while not done:
            if agent.render:
                env.render()

            action = agent.get_action(state)
            next_state, reward, done, info = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])

            # 타임스텝마다 보상 0.1, 에피소드가 중간에 끝나면 -1 보상
            score += reward
            reward = 0.1 if not done or score == 500 else -1

            # 매 타임스텝마다 학습
            loss = agent.train_model(state, action, reward, next_state, done)
            loss_list.append(loss)
            state = next_state

            if done:
                # 에피소드마다 학습 결과 출력
                score_avg = 0.9 * score_avg + 0.1 * score if score_avg != 0 else score
                print("episode: {:3d} | score avg: {:3.2f} | loss: {:.3f}".format(
                      e, score_avg, np.mean(loss_list)))

                # 에피소드마다 학습 결과 그래프로 저장
                scores.append(score_avg)
                episodes.append(e)
                pylab.plot(episodes, scores, 'b')
                pylab.xlabel("episode")
                pylab.ylabel("average score")
                pylab.savefig("./save_graph/graph.png")

                # 이동 평균이 400 이상일 때 종료
                if score_avg > 400:
                    agent.model.save_weights("./save_model/model", save_format="tf")
                    sys.exit()
# Out:
# C:\Users\gypsi\anaconda3\envs\tfproject\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# episode:   0 | score avg: 1.00 | loss: 0.361
# episode:   1 | score avg: 1.00 | loss: 0.360
# episode:   2 | score avg: 1.00 | loss: 0.360
# episode:   3 | score avg: 1.00 | loss: 0.359
# episode:   4 | score avg: 1.00 | loss: 0.357
# episode:   5 | score avg: 1.00 | loss: 0.357
# episode:   6 | score avg: 1.00 | loss: 0.356
# episode:   7 | score avg: 1.00 | loss: 0.356
# episode:   8 | score avg: 1.00 | loss: 0.355
# episode:   9 | score avg: 1.00 | loss: 0.352
# episode:  10 | score avg: 1.00 | loss: 0.352
# episode:  11 | score avg: 1.00 | loss: 0.349
# episode:  12 | score avg: 1.00 | loss: 0.347
# episode:  13 | score avg: 1.00 | loss: 0.346
# episode:  14 | score avg: 1.00 | loss: 0.344
# episode:  15 | score avg: 1.00 | loss: 0.347
# episode:  16 | score avg: 1.00 | loss: 0.346
# episode:  17 | score avg: 1.00 | loss: 0.342
# episode:  18 | score avg: 1.00 | loss: 0.339
# episode:  19 | score avg: 1.00 | loss: 0.341
# episode:  20 | score avg: 1.00 | loss: 0.335
# episode:  21 | score avg: 1.00 | loss: 0.334
# episode:  22 | score avg: 1.00 | loss: 0.331
# episode:  23 | score avg: 1.00 | loss: 0.327
# episode:  24 | score avg: 1.00 | loss: 0.324
# episode:  25 | score avg: 1.00 | loss: 0.324
# episode:  26 | score avg: 1.00 | loss: 0.315
# episode:  27 | score avg: 1.00 | loss: 0.314
# episode:  28 | score avg: 1.00 | loss: 0.319
# episode:  29 | score avg: 1.00 | loss: 0.311
# episode:  30 | score avg: 1.00 | loss: 0.306
# episode:  31 | score avg: 1.00 | loss: 0.299
# episode:  32 | score avg: 1.00 | loss: 0.297
# episode:  33 | score avg: 1.00 | loss: 0.293
# episode:  34 | score avg: 1.00 | loss: 0.298
# episode:  35 | score avg: 1.00 | loss: 0.287
# episode:  36 | score avg: 1.00 | loss: 0.276
# episode:  37 | score avg: 1.00 | loss: 0.278
# episode:  38 | score avg: 1.00 | loss: 0.269
# episode:  39 | score avg: 1.00 | loss: 0.265
# episode:  40 | score avg: 1.00 | loss: 0.258
# episode:  41 | score avg: 1.00 | loss: 0.251
# episode:  42 | score avg: 1.00 | loss: 0.239
# episode:  43 | score avg: 1.00 | loss: 0.237
# episode:  44 | score avg: 1.00 | loss: 0.238
# episode:  45 | score avg: 1.00 | loss: 0.227
# episode:  46 | score avg: 1.00 | loss: 0.227
# episode:  47 | score avg: 1.00 | loss: 0.211
# episode:  48 | score avg: 1.00 | loss: 0.187
# episode:  49 | score avg: 1.00 | loss: 0.190
# episode:  50 | score avg: 1.00 | loss: 0.178
# episode:  51 | score avg: 1.00 | loss: 0.176
# episode:  52 | score avg: 1.00 | loss: 0.173
# episode:  53 | score avg: 1.00 | loss: 0.164
# episode:  54 | score avg: 1.00 | loss: 0.150
# episode:  55 | score avg: 1.00 | loss: 0.128
# episode:  56 | score avg: 1.00 | loss: 0.123
# episode:  57 | score avg: 1.00 | loss: 0.121
# episode:  58 | score avg: 1.00 | loss: 0.107
# episode:  59 | score avg: 1.00 | loss: 0.097
# episode:  60 | score avg: 1.00 | loss: 0.099
# episode:  61 | score avg: 1.00 | loss: 0.083
# episode:  62 | score avg: 1.00 | loss: 0.072
# episode:  63 | score avg: 1.00 | loss: 0.070
# episode:  64 | score avg: 1.00 | loss: 0.055
# episode:  65 | score avg: 1.00 | loss: 0.050
# episode:  66 | score avg: 1.00 | loss: 0.060
# episode:  67 | score avg: 1.00 | loss: 0.036
# episode:  68 | score avg: 1.00 | loss: 0.026
# episode:  69 | score avg: 1.00 | loss: 0.035
# episode:  70 | score avg: 1.00 | loss: 0.013
# episode:  71 | score avg: 1.00 | loss: 0.006
# episode:  72 | score avg: 1.00 | loss: 0.020
# episode:  73 | score avg: 1.00 | loss: 0.006
# episode:  74 | score avg: 1.00 | loss: -0.002
# episode:  75 | score avg: 1.00 | loss: -0.002
# episode:  76 | score avg: 1.00 | loss: -0.005
# episode:  77 | score avg: 1.00 | loss: -0.005
# episode:  78 | score avg: 1.00 | loss: -0.009
# episode:  79 | score avg: 1.00 | loss: -0.007
# episode:  80 | score avg: 1.00 | loss: -0.009
# episode:  81 | score avg: 1.00 | loss: -0.010
# episode:  82 | score avg: 1.00 | loss: -0.008
# episode:  83 | score avg: 1.00 | loss: -0.009
# episode:  84 | score avg: 1.00 | loss: -0.006
# episode:  85 | score avg: 1.00 | loss: -0.001
# episode:  86 | score avg: 1.00 | loss: -0.005
# episode:  87 | score avg: 1.00 | loss: 0.002
# episode:  88 | score avg: 1.00 | loss: 0.011
# episode:  89 | score avg: 1.00 | loss: 0.007
# episode:  90 | score avg: 1.00 | loss: 0.007
# episode:  91 | score avg: 1.00 | loss: 0.013
# episode:  92 | score avg: 1.00 | loss: 0.007
# episode:  93 | score avg: 1.00 | loss: 0.010
# episode:  94 | score avg: 1.00 | loss: 0.009
# episode:  95 | score avg: 1.00 | loss: 0.019
# episode:  96 | score avg: 1.00 | loss: 0.003
# episode:  97 | score avg: 1.00 | loss: 0.012
# episode:  98 | score avg: 1.00 | loss: 0.009
# episode:  99 | score avg: 1.00 | loss: 0.023
# episode: 100 | score avg: 1.00 | loss: 0.018
# episode: 101 | score avg: 1.00 | loss: 0.011
# episode: 102 | score avg: 1.00 | loss: 0.021
# episode: 103 | score avg: 1.00 | loss: 0.014
# episode: 104 | score avg: 1.00 | loss: 0.004
# episode: 105 | score avg: 1.00 | loss: 0.007
# episode: 106 | score avg: 1.00 | loss: 0.009
# episode: 107 | score avg: 1.00 | loss: 0.000
# episode: 108 | score avg: 1.00 | loss: 0.012
# episode: 109 | score avg: 1.00 | loss: 0.006
# episode: 110 | score avg: 1.00 | loss: 0.005
# episode: 111 | score avg: 1.00 | loss: 0.005
# episode: 112 | score avg: 1.00 | loss: -0.004
# episode: 113 | score avg: 1.00 | loss: 0.004
# episode: 114 | score avg: 1.00 | loss: 0.008
# episode: 115 | score avg: 1.00 | loss: 0.001
# episode: 116 | score avg: 1.00 | loss: 0.002
# episode: 117 | score avg: 1.00 | loss: 0.011
# episode: 118 | score avg: 1.00 | loss: 0.002
# episode: 119 | score avg: 1.00 | loss: 0.002
# episode: 120 | score avg: 1.00 | loss: 0.000
# episode: 121 | score avg: 1.00 | loss: 0.004
# episode: 122 | score avg: 1.00 | loss: -0.007
# episode: 123 | score avg: 1.00 | loss: -0.006
# episode: 124 | score avg: 1.00 | loss: -0.004
# episode: 125 | score avg: 1.00 | loss: -0.006
# episode: 126 | score avg: 1.00 | loss: 0.001
# episode: 127 | score avg: 1.00 | loss: -0.004
# episode: 128 | score avg: 1.00 | loss: 0.007
# episode: 129 | score avg: 1.00 | loss: -0.003
# episode: 130 | score avg: 1.00 | loss: 0.002
# episode: 131 | score avg: 1.00 | loss: 0.004
# episode: 132 | score avg: 1.00 | loss: -0.004
# episode: 133 | score avg: 1.00 | loss: -0.007
# episode: 134 | score avg: 1.00 | loss: -0.005
# episode: 135 | score avg: 1.00 | loss: -0.000
# episode: 136 | score avg: 1.00 | loss: -0.004
# episode: 137 | score avg: 1.00 | loss: -0.006
# episode: 138 | score avg: 1.00 | loss: -0.004
# episode: 139 | score avg: 1.00 | loss: -0.001
# episode: 140 | score avg: 1.00 | loss: 0.003
# episode: 141 | score avg: 1.00 | loss: 0.004
# episode: 142 | score avg: 1.00 | loss: -0.001
# episode: 143 | score avg: 1.00 | loss: -0.001
# episode: 144 | score avg: 1.00 | loss: -0.006
# episode: 145 | score avg: 1.00 | loss: -0.001
# episode: 146 | score avg: 1.00 | loss: 0.002
# episode: 147 | score avg: 1.00 | loss: 0.004
# episode: 148 | score avg: 1.00 | loss: 0.001
# episode: 149 | score avg: 1.00 | loss: 0.001
# episode: 150 | score avg: 1.00 | loss: 0.006
# episode: 151 | score avg: 1.00 | loss: 0.000
# episode: 152 | score avg: 1.00 | loss: -0.001
# episode: 153 | score avg: 1.00 | loss: 0.002
# episode: 154 | score avg: 1.00 | loss: 0.001
# episode: 155 | score avg: 1.00 | loss: -0.003
# episode: 156 | score avg: 1.00 | loss: -0.001
# episode: 157 | score avg: 1.00 | loss: 0.007
# episode: 158 | score avg: 1.00 | loss: -0.001
# episode: 159 | score avg: 1.00 | loss: 0.010
# episode: 160 | score avg: 1.00 | loss: -0.003
# episode: 161 | score avg: 1.00 | loss: -0.000
# episode: 162 | score avg: 1.00 | loss: -0.001
# episode: 163 | score avg: 1.00 | loss: 0.004
# episode: 164 | score avg: 1.00 | loss: -0.002
# episode: 165 | score avg: 1.00 | loss: 0.010
# episode: 166 | score avg: 1.00 | loss: -0.005
# episode: 167 | score avg: 1.00 | loss: 0.006
# episode: 168 | score avg: 1.00 | loss: -0.003
# episode: 169 | score avg: 1.00 | loss: -0.001
# episode: 170 | score avg: 1.00 | loss: 0.007
# episode: 171 | score avg: 1.00 | loss: -0.004
# episode: 172 | score avg: 1.00 | loss: -0.000
# episode: 173 | score avg: 1.00 | loss: -0.006
# episode: 174 | score avg: 1.00 | loss: 0.002
# episode: 175 | score avg: 1.00 | loss: -0.005
# episode: 176 | score avg: 1.00 | loss: 0.003
# episode: 177 | score avg: 1.00 | loss: -0.001
# episode: 178 | score avg: 1.00 | loss: 0.007
# episode: 179 | score avg: 1.00 | loss: -0.006
# episode: 180 | score avg: 1.00 | loss: -0.005
# episode: 181 | score avg: 1.00 | loss: -0.002
# episode: 182 | score avg: 1.00 | loss: -0.003
# episode: 183 | score avg: 1.00 | loss: -0.000
# episode: 184 | score avg: 1.00 | loss: -0.003
# episode: 185 | score avg: 1.00 | loss: -0.004
# episode: 186 | score avg: 1.00 | loss: -0.002
# episode: 187 | score avg: 1.00 | loss: -0.003
# episode: 188 | score avg: 1.00 | loss: 0.000
# episode: 189 | score avg: 1.00 | loss: 0.001
# episode: 190 | score avg: 1.00 | loss: -0.003
# episode: 191 | score avg: 1.00 | loss: 0.008
# episode: 192 | score avg: 1.00 | loss: 0.004
# episode: 193 | score avg: 1.00 | loss: 0.001
# episode: 194 | score avg: 1.00 | loss: 0.008
# episode: 195 | score avg: 1.00 | loss: 0.001
# episode: 196 | score avg: 1.00 | loss: -0.005
# episode: 197 | score avg: 1.00 | loss: -0.003
# episode: 198 | score avg: 1.00 | loss: -0.003
# episode: 199 | score avg: 1.00 | loss: 0.003
# episode: 200 | score avg: 1.00 | loss: -0.003
# episode: 201 | score avg: 1.00 | loss: -0.003
# episode: 202 | score avg: 1.00 | loss: -0.001
# episode: 203 | score avg: 1.00 | loss: -0.001
# episode: 204 | score avg: 1.00 | loss: -0.002
# episode: 205 | score avg: 1.00 | loss: 0.003
# episode: 206 | score avg: 1.00 | loss: 0.003
# episode: 207 | score avg: 1.00 | loss: 0.000
# episode: 208 | score avg: 1.00 | loss: 0.000
# episode: 209 | score avg: 1.00 | loss: 0.002
# episode: 210 | score avg: 1.00 | loss: 0.007
# episode: 211 | score avg: 1.00 | loss: 0.009
# episode: 212 | score avg: 1.00 | loss: 0.002
# episode: 213 | score avg: 1.00 | loss: 0.005
# episode: 214 | score avg: 1.00 | loss: 0.000
# episode: 215 | score avg: 1.00 | loss: -0.001
# episode: 216 | score avg: 1.00 | loss: 0.000
# episode: 217 | score avg: 1.00 | loss: 0.004
# episode: 218 | score avg: 1.00 | loss: 0.002
# episode: 219 | score avg: 1.00 | loss: -0.003
# episode: 220 | score avg: 1.00 | loss: 0.004
# episode: 221 | score avg: 1.00 | loss: 0.007
# episode: 222 | score avg: 1.00 | loss: -0.002
# episode: 223 | score avg: 1.00 | loss: 0.002
# episode: 224 | score avg: 1.00 | loss: -0.001
# episode: 225 | score avg: 1.00 | loss: -0.003
# episode: 226 | score avg: 1.00 | loss: -0.002
# episode: 227 | score avg: 1.00 | loss: -0.000
# episode: 228 | score avg: 1.00 | loss: 0.003
# episode: 229 | score avg: 1.00 | loss: 0.000
# episode: 230 | score avg: 1.00 | loss: -0.004
# episode: 231 | score avg: 1.00 | loss: 0.003
# episode: 232 | score avg: 1.00 | loss: -0.005
# episode: 233 | score avg: 1.00 | loss: 0.006
# episode: 234 | score avg: 1.00 | loss: -0.001
# episode: 235 | score avg: 1.00 | loss: -0.005
# episode: 236 | score avg: 1.00 | loss: 0.003
# episode: 237 | score avg: 1.00 | loss: -0.003
# episode: 238 | score avg: 1.00 | loss: -0.004
# episode: 239 | score avg: 1.00 | loss: -0.002
# episode: 240 | score avg: 1.00 | loss: -0.006
# episode: 241 | score avg: 1.00 | loss: -0.006
# episode: 242 | score avg: 1.00 | loss: 0.000
# episode: 243 | score avg: 1.00 | loss: 0.006
# episode: 244 | score avg: 1.00 | loss: -0.004
# episode: 245 | score avg: 1.00 | loss: -0.003
# episode: 246 | score avg: 1.00 | loss: -0.001
# episode: 247 | score avg: 1.00 | loss: -0.003
# episode: 248 | score avg: 1.00 | loss: 0.002
# episode: 249 | score avg: 1.00 | loss: 0.002
# episode: 250 | score avg: 1.00 | loss: 0.002
# episode: 251 | score avg: 1.00 | loss: 0.002
# episode: 252 | score avg: 1.00 | loss: -0.000
# episode: 253 | score avg: 1.00 | loss: 0.002
# episode: 254 | score avg: 1.00 | loss: -0.002
# episode: 255 | score avg: 1.00 | loss: 0.004
# episode: 256 | score avg: 1.00 | loss: 0.002
# episode: 257 | score avg: 1.00 | loss: 0.003
# episode: 258 | score avg: 1.00 | loss: -0.003
# episode: 259 | score avg: 1.00 | loss: -0.003
# episode: 260 | score avg: 1.00 | loss: 0.007
# episode: 261 | score avg: 1.00 | loss: 0.004
# episode: 262 | score avg: 1.00 | loss: -0.001
# episode: 263 | score avg: 1.00 | loss: 0.000
# episode: 264 | score avg: 1.00 | loss: 0.007
# episode: 265 | score avg: 1.00 | loss: 0.007
# episode: 266 | score avg: 1.00 | loss: 0.001
# episode: 267 | score avg: 1.00 | loss: -0.002
# episode: 268 | score avg: 1.00 | loss: -0.004
# episode: 269 | score avg: 1.00 | loss: -0.006
# episode: 270 | score avg: 1.00 | loss: 0.000
# episode: 271 | score avg: 1.00 | loss: 0.003
# episode: 272 | score avg: 1.00 | loss: -0.003
# episode: 273 | score avg: 1.00 | loss: -0.000
# episode: 274 | score avg: 1.00 | loss: -0.001
# episode: 275 | score avg: 1.00 | loss: 0.001
# episode: 276 | score avg: 1.00 | loss: 0.005
# episode: 277 | score avg: 1.00 | loss: 0.005
# episode: 278 | score avg: 1.00 | loss: -0.001
# episode: 279 | score avg: 1.00 | loss: -0.002
# episode: 280 | score avg: 1.00 | loss: -0.003
# episode: 281 | score avg: 1.00 | loss: -0.002
# episode: 282 | score avg: 1.00 | loss: 0.001
# episode: 283 | score avg: 1.00 | loss: 0.007
# episode: 284 | score avg: 1.00 | loss: -0.002
# episode: 285 | score avg: 1.00 | loss: 0.004
# episode: 286 | score avg: 1.00 | loss: 0.007
# episode: 287 | score avg: 1.00 | loss: 0.007
# episode: 288 | score avg: 1.00 | loss: -0.004
# episode: 289 | score avg: 1.00 | loss: -0.004
# episode: 290 | score avg: 1.00 | loss: -0.001
# episode: 291 | score avg: 1.00 | loss: -0.003
# episode: 292 | score avg: 1.00 | loss: -0.002
# episode: 293 | score avg: 1.00 | loss: 0.000
# episode: 294 | score avg: 1.00 | loss: 0.000
# episode: 295 | score avg: 1.00 | loss: 0.001
# episode: 296 | score avg: 1.00 | loss: 0.006
# episode: 297 | score avg: 1.00 | loss: -0.003
# episode: 298 | score avg: 1.00 | loss: -0.002
# episode: 299 | score avg: 1.00 | loss: 0.001
# episode: 300 | score avg: 1.00 | loss: -0.003
# episode: 301 | score avg: 1.00 | loss: -0.001
# episode: 302 | score avg: 1.00 | loss: -0.003
# episode: 303 | score avg: 1.00 | loss: 0.004
# episode: 304 | score avg: 1.00 | loss: 0.000
# episode: 305 | score avg: 1.00 | loss: 0.003
# episode: 306 | score avg: 1.00 | loss: -0.002
# episode: 307 | score avg: 1.00 | loss: -0.002
# episode: 308 | score avg: 1.00 | loss: 0.005
# episode: 309 | score avg: 1.00 | loss: -0.000
# episode: 310 | score avg: 1.00 | loss: 0.002
# episode: 311 | score avg: 1.00 | loss: 0.001
# episode: 312 | score avg: 1.00 | loss: 0.004
# episode: 313 | score avg: 1.00 | loss: 0.003
# episode: 314 | score avg: 1.00 | loss: 0.003
# episode: 315 | score avg: 1.00 | loss: -0.001
# episode: 316 | score avg: 1.00 | loss: -0.003
# episode: 317 | score avg: 1.00 | loss: -0.002
# episode: 318 | score avg: 1.00 | loss: 0.006
# episode: 319 | score avg: 1.00 | loss: -0.004
# episode: 320 | score avg: 1.00 | loss: -0.002
# episode: 321 | score avg: 1.00 | loss: 0.001
# episode: 322 | score avg: 1.00 | loss: 0.001
# episode: 323 | score avg: 1.00 | loss: -0.002
# episode: 324 | score avg: 1.00 | loss: 0.004
# episode: 325 | score avg: 1.00 | loss: 0.002
# episode: 326 | score avg: 1.00 | loss: 0.002
# episode: 327 | score avg: 1.00 | loss: -0.003
# episode: 328 | score avg: 1.00 | loss: -0.003
# episode: 329 | score avg: 1.00 | loss: -0.001
# episode: 330 | score avg: 1.00 | loss: 0.003
# episode: 331 | score avg: 1.00 | loss: 0.003
# episode: 332 | score avg: 1.00 | loss: 0.002
# episode: 333 | score avg: 1.00 | loss: 0.005
# episode: 334 | score avg: 1.00 | loss: 0.000
# episode: 335 | score avg: 1.00 | loss: -0.001
# episode: 336 | score avg: 1.00 | loss: -0.003
# episode: 337 | score avg: 1.00 | loss: 0.002
# episode: 338 | score avg: 1.00 | loss: -0.001
# episode: 339 | score avg: 1.00 | loss: -0.005
# episode: 340 | score avg: 1.00 | loss: 0.001
# episode: 341 | score avg: 1.00 | loss: -0.005
# episode: 342 | score avg: 1.00 | loss: 0.000
# episode: 343 | score avg: 1.00 | loss: -0.002
# episode: 344 | score avg: 1.00 | loss: -0.006
# episode: 345 | score avg: 1.00 | loss: -0.002
# episode: 346 | score avg: 1.00 | loss: -0.002
# episode: 347 | score avg: 1.00 | loss: -0.002
# episode: 348 | score avg: 1.00 | loss: -0.004
# episode: 349 | score avg: 1.00 | loss: -0.002
# episode: 350 | score avg: 1.00 | loss: 0.001
# episode: 351 | score avg: 1.00 | loss: -0.002
# episode: 352 | score avg: 1.00 | loss: -0.001
# episode: 353 | score avg: 1.00 | loss: 0.001
# episode: 354 | score avg: 1.00 | loss: 0.000
# episode: 355 | score avg: 1.00 | loss: 0.007
# episode: 356 | score avg: 1.00 | loss: 0.002
# episode: 357 | score avg: 1.00 | loss: 0.004
# episode: 358 | score avg: 1.00 | loss: 0.008
# episode: 359 | score avg: 1.00 | loss: 0.006
# episode: 360 | score avg: 1.00 | loss: 0.005
# episode: 361 | score avg: 1.00 | loss: -0.000
# episode: 362 | score avg: 1.00 | loss: -0.000
# episode: 363 | score avg: 1.00 | loss: -0.001
# episode: 364 | score avg: 1.00 | loss: -0.000
